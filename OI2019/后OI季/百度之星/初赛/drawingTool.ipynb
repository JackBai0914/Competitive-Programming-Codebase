# %%
import matplotlib.pyplot as plt
import networkx as nx
import pylab as plt

# %%
print ("hello?")
# Out:
# hello?

# %%
fig = plt.figure(figsize=(18, 4))
x = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000]
train_loss = [11.38724, 10.65646, 9.44395, 8.07883, 8.03897, 7.47289, 7.34222, 6.83688, 6.61482, 6.67000, 6.35091, 6.32876, 6.28155, 6.24954, 6.21875, 6.22095, 6.19607, 6.17603, 6.17354, 6.19982]
train_auc = [0.506666098954765, 0.6818342513492834, 0.6825103446140268, 0.7238107403350273, 0.782127010054952, 0.6793601886867922, 0.6788076372733829, 0.798095842671549, 0.7778640097749668, 0.7583831048938057, 0.801301479534631, 0.8002860493831939, 0.763000279985188, 0.7924206590361025, 0.7679213099694081, 0.798186805601252, 0.7806522493648723, 0.7990106329858677, 0.7692651098458017, 0.7936947851791065]
train_f1 = [0.08961303462321792, 0.46089385474860334, 0.4722222222222222, 0.5080545229244114, 0.5088868101028999, 0.4554455445544554, 0.4418262150220913, 0.5234159779614325, 0.5468926553672316, 0.5361596009975063, 0.5504201680672268, 0.5448851774530272, 0.5356200527704486, 0.5595375722543353, 0.5284974093264249, 0.5487944890929966, 0.5419847328244275, 0.5460829493087558, 0.5221932114882507, 0.5421686746987951]
val_loss = [3.75316, 1.82464, 2.10946, 1.81497, 1.62474, 1.26480, 1.20399, 1.15897, 0.82953, 0.65657, 0.63988, 0.61229, 0.57527, 0.55309, 0.54322, 0.54340, 0.53717, 0.53548, 0.53506, 0.53637]
val_auc = [0.45699473057963624, 0.6239163691993881, 0.6159484956654767, 0.6587200407955126, 0.7492563318035017, 0.623703892571817, 0.6283783783783783, 0.7703127655957845, 0.7250977392486826, 0.6903365629780724, 0.7567567567567567, 0.7548444671086181, 0.7060598334183239, 0.7343617202107768, 0.7129440761516234, 0.7438806731259562, 0.7264150943396226, 0.7444756076831548, 0.7143039265680775, 0.7451555328913819]
val_f1 = [0.15625, 0.4186046511627907, 0.41463414634146334, 0.4731182795698925, 0.512396694214876, 0.4470588235294118, 0.41463414634146334, 0.5042016806722689, 0.49019607843137253, 0.48421052631578954, 0.5272727272727273, 0.5137614678899083, 0.5454545454545454, 0.5106382978723404, 0.5393258426966292, 0.5, 0.5393258426966292, 0.49484536082474223, 0.5287356321839081, 0.5161290322580645]

p1 = fig.add_subplot(131)
plt.xlabel('# epoch')
plt.ylabel('loss of training data')
p1.plot(x, train_loss, color='b', linestyle='-', marker='x')
p2 = fig.add_subplot(132)
plt.xlabel('# epoch')
plt.ylabel('AUC of training data')
plt.ylim(0, 1)
p2.plot(x, train_auc, color='b', linestyle='-', marker='x')
p3 = fig.add_subplot(133)
plt.xlabel('# epoch')
plt.ylabel('f1 of training data')
plt.ylim(0, 1)
p3.plot(x, train_f1, color='b', linestyle='-', marker='x')
plt.savefig("train_track.png",dpi=120)


##################################hyper variable
# fig = plt.figure(figsize=(18, 4))
# LR = fig.add_subplot(131)
# learning_rate=[0.0001, 0.0005, 0.001, 0.005, 0.01]
# test_AUC=[76.460, 79.003, 79.5057, 78.687, 78.687]
# plt.xlabel('learning rate')
# plt.ylabel('AUC')
# # plt.xlim(0, 10)
# plt.ylim(76, 80)
# LR.set_xscale('log')
# LR.plot(learning_rate, test_AUC, color='b', linestyle='-', marker='.')

# DP = fig.add_subplot(132)
# DP_rate=[0.3, 0.4, 0.5, 0.6, 0.7]
# AUC=[79.218, 79.017, 79.5057, 79.218, 79.0173333333333]
# plt.xlabel('dropout weight')
# plt.ylabel('AUC')
# # plt.xlim(0, 10)
# plt.ylim(76, 80)
# DP.plot(DP_rate, AUC, color='b', linestyle='-', marker='s')

# LP = fig.add_subplot(132)
# LP_rate=[0.3, 0.4, 0.5, 0.6, 0.7]
# AUC=[79.218, 79.017, 79.5057, 79.218, 79.0173333333333]
# plt.xlabel('LP weight')
# plt.ylabel('AUC')
# # plt.xlim(0, 10)
# plt.ylim(76, 80)
# LP.plot(LP_rate, AUC, color='b', linestyle='-', marker='s')
# plt.subplot(122)
# plt.plot(x, y, color='b', linestyle='-', marker='s')
# plt.savefig("test.png",dpi=120)

# %%
fig2 = plt.figure(figsize=(18, 4))
p1 = fig2.add_subplot(131)
plt.xlabel('# epoch')
plt.ylabel('loss of validation data')
p1.plot(x, val_loss, color='b', linestyle='-', marker='x')
p2 = fig2.add_subplot(132)
plt.xlabel('# epoch')
plt.ylabel('AUC of validation data')
plt.ylim(0, 1)
p2.plot(x, val_auc, color='b', linestyle='-', marker='x')
p3 = fig2.add_subplot(133)
plt.xlabel('# epoch')
plt.ylabel('f1 of validation data')
plt.ylim(0, 1)
p3.plot(x, val_f1, color='b', linestyle='-', marker='x')

plt.savefig("train_track2.png",dpi=120)

# %%
##################################hyper variable
fig3 = plt.figure(figsize=(18, 4))
LR = fig3.add_subplot(131)
learning_rate=[0.0001, 0.0005, 0.001, 0.005, 0.01]
test_AUC=[76.460, 79.003, 79.5057, 78.687, 78.687]
plt.xlabel('learning rate')
plt.ylabel('AUC')
# plt.xlim(0, 10)
plt.ylim(76, 80)
LR.set_xscale('log')
LR.plot(learning_rate, test_AUC, color='b', linestyle='-', marker='x')

DP = fig3.add_subplot(132)
DP_rate=[0.3, 0.4, 0.5, 0.6, 0.7]
AUC=[79.218, 79.017, 79.5057, 79.218, 79.0173333333333]
plt.xlabel('dropout weight')
plt.ylabel('AUC')
# plt.xlim(0, 10)
plt.ylim(76, 80)
DP.plot(DP_rate, AUC, color='b', linestyle='-', marker='x')

LP = fig3.add_subplot(133)
LP_rate=[0.3, 0.4, 0.5, 0.7, 1.0]
AUC=[78.234, 78.558, 79.5057, 79.201, 79.181]
plt.xlabel('LP weight')
plt.ylabel('AUC')
# plt.xlim(0, 10)
plt.ylim(76, 80)
LP.plot(LP_rate, AUC, color='b', linestyle='-', marker='x')
plt.savefig("hyperparameter1.png",dpi=120)
